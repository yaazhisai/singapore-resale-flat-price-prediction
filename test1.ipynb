# %%
import pandas as pd

# %%
df1=pd.read_csv("C:/Users/yaazhisai/Desktop/singapore resale/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df2=pd.read_csv("C:/Users/yaazhisai/Desktop/singapore resale/ResaleFlatPricesBasedonApprovalDate19901999.csv")
df3=pd.read_csv("C:/Users/yaazhisai/Desktop/singapore resale/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df4=pd.read_csv("C:/Users/yaazhisai/Desktop/singapore resale/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
df5=pd.read_csv("C:/Users/yaazhisai/Desktop/singapore resale/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")

# %%
df_new1=pd.concat([df2,df1,df5,df3,df4],axis=0,ignore_index=True)

# %%
df_raw=pd.concat([df2,df1,df5,df3,df4],axis=0,ignore_index=True)

# %%
df_new1
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 929319  2024-07      YISHUN     4 ROOM   719      YISHUN ST 71     07 TO 09
# 929320  2024-07      YISHUN     5 ROOM   776      YISHUN AVE 2     07 TO 09
# 929321  2024-07      YISHUN     5 ROOM  508B      YISHUN AVE 4     04 TO 06
# 929322  2024-07      YISHUN     5 ROOM  674B      YISHUN AVE 4     01 TO 03
# 929323  2024-07      YISHUN  EXECUTIVE   277      YISHUN ST 22     01 TO 03
#
# ...

# %%
df_new1.head(2)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN

# %%
df_new1.drop(columns='remaining_lease',inplace=True)

# %%
df_new1['month']=df_new1['month'].astype('datetime64[ns]')

# %%
df_new1['salemonth']=df_new1['month'].dt.month

# %%
df_new1['saleyear']=df_new1['month'].dt.year

# %%
df_new1['rem_lease_year']=99-(df_new1['saleyear']-df_new1['lease_commence_date'])

# %%
df_new1.drop_duplicates(inplace=True)

# %%
df_new1['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
df_new1['flat_model'].replace(to_replace=["IMPROVED-MAISONETTE",'Improved-Maisonette','Improved'],
           value="IMPROVED",inplace=True)
# Out:
# C:\Users\yaazhisai\AppData\Local\Temp\ipykernel_12292\3655819092.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_new1['flat_model'].replace(to_replace=['New Generation'],value=['NEW GENERATION'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Model A'],value=['MODEL A'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Standard'],value=['STANDARD'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Simplified'],value=['SIMPLIFIED'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Apartment'],value=['APARTMENT'],inplace=True)

# %%
df_new1['flat_model'].replace(to_replace=['2-room'],value=['2-ROOM'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Multi Generation'],value=['MULTI GENERATION'],inplace=True)

# %%
df_new1['flat_model'].replace(to_replace=['Premium Apartment'],value=['PREMIUM APARTMENT'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Maisonette'],value=['MAISONETTE'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Model A-Maisonette'],value=['MODEL A-MAISONETTE'],inplace=True)
df_new1['flat_model'].replace(to_replace=['Terrace'],value=['TERRACE'],inplace=True)

# %%
df_new1=df_new1.drop(columns=['month','block','street_name'],axis=0)

# %%
df_new1['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'MULTI GENERATION', 'PREMIUM APARTMENT', 'Adjoined flat',
#        'Premium Maisonette', 'Model A2', 'DBSS', 'Type S1', 'Type S2',
#        'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
df_new1
# Out:
#               town  flat_type storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 1       ANG MO KIO     1 ROOM     04 TO 06            31.0        IMPROVED
# 2       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 3       ANG MO KIO     1 ROOM     07 TO 09            31.0        IMPROVED
# 4       ANG MO KIO     3 ROOM     04 TO 06            73.0  NEW GENERATION
# ...            ...        ...          ...             ...             ...
# 929319      YISHUN     4 ROOM     07 TO 09            84.0      SIMPLIFIED
# 929320      YISHUN     5 ROOM     07 TO 09           132.0        IMPROVED
# 929321      YISHUN     5 ROOM     04 TO 06           113.0        IMPROVED
# 929322      YISHUN     5 ROOM     01 TO 03           112.0        IMPROVED
# 929323      YISHUN  EXECUTIVE     01 TO 03           146.0      MAISONETTE
#
# ...

# %%
df_new1['town'].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
df_new1['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df_new1['flat_type']=df_new1['flat_type'].replace('MULTI-GENERATION','MULTI GENERATION')

# %%
df_new1.drop(columns=['resale_price'],inplace=True)

# %%
df_new1= df_new1.query('rem_lease_year <= 99')

# %%
df_new1.head(2)
# Out:
#          town flat_type storey_range  floor_area_sqm flat_model  \
# 0  ANG MO KIO    1 ROOM     10 TO 12            31.0   IMPROVED
# 1  ANG MO KIO    1 ROOM     04 TO 06            31.0   IMPROVED
#
#    lease_commence_date  salemonth  saleyear  rem_lease_year
# 0                 1977          1      1990              86
# 1                 1977          1      1990              86

# %%
df_new1.to_csv('C:/Users/yaazhisai/Desktop/singapore resale/df_clean.csv')

# %%
df_raw.to_csv('C:/Users/yaazhisai/Desktop/singapore resale/df_raw1.csv')

# %%
df_raw['lease_commence_date'].unique()
# Out:
# array([1977, 1976, 1978, 1979, 1984, 1980, 1985, 1981, 1982, 1986, 1972,
#        1983, 1973, 1969, 1975, 1971, 1974, 1967, 1970, 1968, 1988, 1987,
#        1989, 1990, 1992, 1993, 1994, 1991, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 1966, 2002, 2006, 2003, 2005, 2004, 2008, 2007, 2009,
#        2010, 2012, 2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#       dtype=int64)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929324 entries, 0 to 929323
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                929324 non-null  object
#  1   town                 929324 non-null  object
#  2   flat_type            929324 non-null  object
#  3   block                929324 non-null  object
#  4   street_name          929324 non-null  object
#  5   storey_range         929324 non-null  object
#  6   floor_area_sqm       929324 non-null  float64
#  7   flat_model           929324 non-null  object
#  8   lease_commence_date  929324 non-null  int64
#  9   resale_price         929324 non-null  float64
#  10  remaining_lease      220274 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 78.0+ MB

# %%
df_raw['month']=df_raw['month'].astype('datetime64[ns]')

# %%
df_raw['saleyear']=df_raw['month'].dt.year

# %%
df_raw['rem_lease_year']=99-(df_raw['saleyear']-df_raw['lease_commence_date'])

# %%
df_raw=df_raw.query('rem_lease_year <= 99')

# %%
df_raw
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 929319 2024-07-01      YISHUN     4 ROOM   719      YISHUN ST 71     07 TO 09
# 929320 2024-07-01      YISHUN     5 ROOM   776      YISHUN AVE 2     07 TO 09
# 929321 2024-07-01      YISHUN     5 ROOM  508B      YISHUN AVE 4     04 TO 06
# 929322 2024-07-01      YISHUN     5 ROOM  674B      YISHUN AVE 4     01 TO 03
# 929323 2024-07-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     01 TO 03
#
# ...

# %%
df_new1
# Out:
#               town  flat_type storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 1       ANG MO KIO     1 ROOM     04 TO 06            31.0        IMPROVED
# 2       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 3       ANG MO KIO     1 ROOM     07 TO 09            31.0        IMPROVED
# 4       ANG MO KIO     3 ROOM     04 TO 06            73.0  NEW GENERATION
# ...            ...        ...          ...             ...             ...
# 929319      YISHUN     4 ROOM     07 TO 09            84.0      SIMPLIFIED
# 929320      YISHUN     5 ROOM     07 TO 09           132.0        IMPROVED
# 929321      YISHUN     5 ROOM     04 TO 06           113.0        IMPROVED
# 929322      YISHUN     5 ROOM     01 TO 03           112.0        IMPROVED
# 929323      YISHUN  EXECUTIVE     01 TO 03           146.0      MAISONETTE
#
#         lease_commence_date  salemonth  saleyear  rem_lease_year
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
df_new1['town_en']=OrdinalEncoder().fit_transform(df_new1[['town']])
df_new1['storey_en']=OrdinalEncoder().fit_transform(df_new1[['storey_range']])
df_new1['flat_model_en']=OrdinalEncoder().fit_transform(df_new1[['flat_model']])
df_new1['flat_type_en']=df_new1['flat_type'].map({'1 ROOM':1,'2 ROOM':2, '3 ROOM':3,'4 ROOM':4,'5 ROOM':5,'EXECUTIVE':6,'MULTI GENERATION':7})
# Out:
# C:\Users\yaazhisai\AppData\Local\Temp\ipykernel_12292\3655273503.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\yaazhisai\AppData\Local\Temp\ipykernel_12292\3655273503.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\yaazhisai\AppData\Local\Temp\ipykernel_12292\3655273503.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_new1.head(2)
# Out:
#          town flat_type storey_range  floor_area_sqm flat_model  \
# 0  ANG MO KIO    1 ROOM     10 TO 12            31.0   IMPROVED
# 1  ANG MO KIO    1 ROOM     04 TO 06            31.0   IMPROVED
#
#    lease_commence_date  salemonth  saleyear  rem_lease_year  town_en  \
# 0                 1977          1      1990              86      0.0
# 1                 1977          1      1990              86      0.0
#
#    storey_en  flat_model_en  flat_type_en
# 0        5.0            5.0             1
# 1        2.0            5.0             1

# %%
df_new2=df_new1.copy()

# %%
df_new1
# Out:
#               town  flat_type storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 1       ANG MO KIO     1 ROOM     04 TO 06            31.0        IMPROVED
# 2       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 3       ANG MO KIO     1 ROOM     07 TO 09            31.0        IMPROVED
# 4       ANG MO KIO     3 ROOM     04 TO 06            73.0  NEW GENERATION
# ...            ...        ...          ...             ...             ...
# 929319      YISHUN     4 ROOM     07 TO 09            84.0      SIMPLIFIED
# 929320      YISHUN     5 ROOM     07 TO 09           132.0        IMPROVED
# 929321      YISHUN     5 ROOM     04 TO 06           113.0        IMPROVED
# 929322      YISHUN     5 ROOM     01 TO 03           112.0        IMPROVED
# 929323      YISHUN  EXECUTIVE     01 TO 03           146.0      MAISONETTE
#
# ...

# %%
df_new2['town']
# Out:
# 0         ANG MO KIO
# 1         ANG MO KIO
# 2         ANG MO KIO
# 3         ANG MO KIO
# 4         ANG MO KIO
#              ...
# 929319        YISHUN
# 929320        YISHUN
# 929321        YISHUN
# 929322        YISHUN
# 929323        YISHUN
# Name: town, Length: 927301, dtype: object

# %%
town_en=df_new2[df_new2['town']=='YISHUN']['town_en'].iloc[0]
town_en
# Out:
# 26.0

# %%
flat_type_en=df_new2[df_new2['flat_type']=='EXECUTIVE']['flat_type_en'].iloc[0]
flat_type_en
# Out:
# 6

# %%
lease_commence_date_en=df_new1[df_new1['lease_commence_date']=='1995']['lease_commence_date_en'].iloc[0]
lease_commence_date_en
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\yaazhisai\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lease_commence_date_en'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[291], line 1
# ...

# %%
flat_model_en=df_new2[df_new2['flat_model']=='IMPROVED']['flat_model_en'].iloc[0]
flat_model_en
# Out:
# 5.0

# %%
storey_en=df_new2[df_new2['storey_range']=='04 TO 06']['storey_en'].iloc[0]
storey_en
# Out:
# 2.0

# %%
t=df_new1['town'].unique()

# %%
type(t)
# Out:
# numpy.ndarray

# %%
df_new1
# Out:
#               town  flat_type storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 1       ANG MO KIO     1 ROOM     04 TO 06            31.0        IMPROVED
# 2       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 3       ANG MO KIO     1 ROOM     07 TO 09            31.0        IMPROVED
# 4       ANG MO KIO     3 ROOM     04 TO 06            73.0  NEW GENERATION
# ...            ...        ...          ...             ...             ...
# 929319      YISHUN     4 ROOM     07 TO 09            84.0      SIMPLIFIED
# 929320      YISHUN     5 ROOM     07 TO 09           132.0        IMPROVED
# 929321      YISHUN     5 ROOM     04 TO 06           113.0        IMPROVED
# 929322      YISHUN     5 ROOM     01 TO 03           112.0        IMPROVED
# 929323      YISHUN  EXECUTIVE     01 TO 03           146.0      MAISONETTE
#
# ...

# %%
df_raw
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 929319 2024-07-01      YISHUN     4 ROOM   719      YISHUN ST 71     07 TO 09
# 929320 2024-07-01      YISHUN     5 ROOM   776      YISHUN AVE 2     07 TO 09
# 929321 2024-07-01      YISHUN     5 ROOM  508B      YISHUN AVE 4     04 TO 06
# 929322 2024-07-01      YISHUN     5 ROOM  674B      YISHUN AVE 4     01 TO 03
# 929323 2024-07-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     01 TO 03
#
# ...

# %%
df_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 927301 entries, 0 to 929323
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   town            927301 non-null  object
#  1   flat_type       927301 non-null  object
#  2   storey_range    927301 non-null  object
#  3   floor_area_sqm  927301 non-null  float64
#  4   flat_model      927301 non-null  object
#  5   rem_lease_year  927301 non-null  int64
#  6   town_en         927301 non-null  float64
#  7   storey_en       927301 non-null  float64
#  8   flat_model_en   927301 non-null  float64
#  9   flat_type_en    927301 non-null  int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 77.8+ MB

# %%
df_new1
# Out:
#               town  flat_type storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 1       ANG MO KIO     1 ROOM     04 TO 06            31.0        IMPROVED
# 2       ANG MO KIO     1 ROOM     10 TO 12            31.0        IMPROVED
# 3       ANG MO KIO     1 ROOM     07 TO 09            31.0        IMPROVED
# 4       ANG MO KIO     3 ROOM     04 TO 06            73.0  NEW GENERATION
# ...            ...        ...          ...             ...             ...
# 929319      YISHUN     4 ROOM     07 TO 09            84.0      SIMPLIFIED
# 929320      YISHUN     5 ROOM     07 TO 09           132.0        IMPROVED
# 929321      YISHUN     5 ROOM     04 TO 06           113.0        IMPROVED
# 929322      YISHUN     5 ROOM     01 TO 03           112.0        IMPROVED
# 929323      YISHUN  EXECUTIVE     01 TO 03           146.0      MAISONETTE
#
# ...

# %%
df_raw['town'].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
t=['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
       'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
       'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
       'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
       'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
       'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
       'PUNGGOL']

# %%
df_raw['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
c=['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
       'MULTI GENERATION', 'MULTI-GENERATION']

# %%
d=df_raw.groupby(['town','flat_type'])[['resale_price']].min()
d.reset_index(inplace= True)
d1=df_raw.groupby(['town','flat_type'])[['resale_price']].max()
d1.reset_index(inplace= True)

# %%
d
# Out:
#            town         flat_type  resale_price
# 0    ANG MO KIO            1 ROOM        5600.0
# 1    ANG MO KIO            2 ROOM       22000.0
# 2    ANG MO KIO            3 ROOM       30000.0
# 3    ANG MO KIO            4 ROOM       47000.0
# 4    ANG MO KIO            5 ROOM       78300.0
# ..          ...               ...           ...
# 132      YISHUN            4 ROOM       41700.0
# 133      YISHUN            5 ROOM       70500.0
# 134      YISHUN         EXECUTIVE      115000.0
# 135      YISHUN  MULTI GENERATION      141000.0
# 136      YISHUN  MULTI-GENERATION      330000.0
#
# [137 rows x 3 columns]

# %%
d1
# Out:
#            town         flat_type  resale_price
# 0    ANG MO KIO            1 ROOM      142000.0
# 1    ANG MO KIO            2 ROOM      331888.0
# 2    ANG MO KIO            3 ROOM      780000.0
# 3    ANG MO KIO            4 ROOM     1038888.0
# 4    ANG MO KIO            5 ROOM     1268000.0
# ..          ...               ...           ...
# 132      YISHUN            4 ROOM      778000.0
# 133      YISHUN            5 ROOM      875000.0
# 134      YISHUN         EXECUTIVE     1080000.0
# 135      YISHUN  MULTI GENERATION      705000.0
# 136      YISHUN  MULTI-GENERATION     1200000.0
#
# [137 rows x 3 columns]

# %%
df_raw
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 929319 2024-07-01      YISHUN     4 ROOM   719      YISHUN ST 71     07 TO 09
# 929320 2024-07-01      YISHUN     5 ROOM   776      YISHUN AVE 2     07 TO 09
# 929321 2024-07-01      YISHUN     5 ROOM  508B      YISHUN AVE 4     04 TO 06
# 929322 2024-07-01      YISHUN     5 ROOM  674B      YISHUN AVE 4     01 TO 03
# 929323 2024-07-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     01 TO 03
#
# ...

# %%
ss=df_raw.groupby(['town'])[['resale_price']].mean()
ss.reset_index(inplace= True)

# %%
ss['town']
# Out:
# 0          ANG MO KIO
# 1               BEDOK
# 2              BISHAN
# 3         BUKIT BATOK
# 4         BUKIT MERAH
# 5       BUKIT PANJANG
# 6         BUKIT TIMAH
# 7        CENTRAL AREA
# 8       CHOA CHU KANG
# 9            CLEMENTI
# 10            GEYLANG
# 11            HOUGANG
# 12        JURONG EAST
# 13        JURONG WEST
# 14    KALLANG/WHAMPOA
# 15       LIM CHU KANG
# 16      MARINE PARADE
# 17          PASIR RIS
# 18            PUNGGOL
# 19         QUEENSTOWN
# 20          SEMBAWANG
# 21           SENGKANG
# 22          SERANGOON
# 23           TAMPINES
# 24          TOA PAYOH
# 25          WOODLANDS
# 26             YISHUN
# Name: town, dtype: object

# %%
ss
# Out:
#                town   resale_price
# 0        ANG MO KIO  258638.306248
# 1             BEDOK  276596.611420
# 2            BISHAN  423582.021745
# 3       BUKIT BATOK  281274.011178
# 4       BUKIT MERAH  355894.775028
# 5     BUKIT PANJANG  334574.842034
# 6       BUKIT TIMAH  455630.647594
# 7      CENTRAL AREA  344811.515863
# 8     CHOA CHU KANG  348564.182549
# 9          CLEMENTI  286213.456910
# 10          GEYLANG  275537.331317
# 11          HOUGANG  320974.145905
# 12      JURONG EAST  283436.120781
# 13      JURONG WEST  295119.387005
# 14  KALLANG/WHAMPOA  327499.513060
# 15     LIM CHU KANG   63660.937500
# 16    MARINE PARADE  340411.764647
# 17        PASIR RIS  406690.176339
# 18          PUNGGOL  486402.373060
# 19       QUEENSTOWN  301409.741677
# 20        SEMBAWANG  386726.807346
# 21         SENGKANG  439822.069417
# 22        SERANGOON  329544.996364
# 23         TAMPINES  336883.771892
# 24        TOA PAYOH  307257.818492
# 25        WOODLANDS  314227.968102
# ...
